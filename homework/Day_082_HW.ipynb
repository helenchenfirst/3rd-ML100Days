# %% [markdown]
# ## Work
# 1. 請比較使用不同層數以及不同 Dropout rate 對訓練的效果
# 2. 將 optimizer 改成使用 Adam 並加上適當的 dropout rate 檢視結果

# %%
import os
import keras
import itertools
# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = ""
# Out:
# Using TensorFlow backend.

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
"""Code Here
    建立你的神經網路
"""
from keras.layers import Dropout

def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128], drp_ratio=0.2):
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(input_layer)
            x = Dropout(drp_ratio)(x)
        else:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
            x = Dropout(drp_ratio)(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
"""Code Here
設定超參數
"""
LEARNING_RATE = 1e-3
EPOCHS = 50
BATCH_SIZE = 256
MOMENTUM = 0.95
Dropout_EXP = [0.1, 0.25, 0,5]

# %%
results = {}
"""Code Here
撰寫你的訓練流程並將結果用 dictionary 紀錄
"""
for lr in Dropout_EXP:
    keras.backend.clear_session() # 把舊的 Graph 清掉
    print("Experiment with Dropout = %.6f" % (lr))

    model = build_mlp(input_shape=x_train.shape[1:], drp_ratio=lr)
    model.summary()
    optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
    model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

    model.fit(x_train, y_train, 
              epochs=EPOCHS, 
              batch_size=BATCH_SIZE, 
              validation_data=(x_test, y_test), 
              shuffle=True)
    
    # Collect results
    train_loss = model.history.history["loss"]
    valid_loss = model.history.history["val_loss"]
    train_acc = model.history.history["acc"]
    valid_acc = model.history.history["val_acc"]
    
    exp_name_tag = "exp-lr-%s" % st(lr)
    results[exp_name_tag] = {'train-loss': train_loss,
                             'valid-loss': valid_loss,
                             'train-acc': train_acc,
                             'valid-acc': valid_acc}
# Out:
# Experiment with Dropout = 0.100000
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 12s 238us/step - loss: 2.1222 - accuracy: 0.2179 - val_loss: 1.9334 - val_accuracy: 0.3168
# Epoch 2/50
# 50000/50000 [==============================] - 11s 218us/step - loss: 1.9120 - accuracy: 0.3144 - val_loss: 1.8147 - val_accuracy: 0.3655
# Epoch 3/50
# 50000/50000 [==============================] - 11s 217us/step - loss: 1.8229 - accuracy: 0.3483 - val_loss: 1.7413 - val_accuracy: 0.3806
# Epoch 4/50
# 50000/50000 [==============================] - 11s 216us/step - loss: 1.7631 - accuracy: 0.3697 - val_loss: 1.6878 - val_accuracy: 0.4037
# Epoch 5/50
# 50000/50000 [==============================] - 11s 216us/step - loss: 1.7167 - accuracy: 0.3891 - val_loss: 1.6457 - val_accuracy: 0.4200
# Epoch 6/50
# 50000/50000 [==============================] - 11s 220us/step - loss: 1.6792 - accuracy: 0.4027 - val_loss: 1.6126 - val_accuracy: 0.4284
# Epoch 7/50
# 50000/50000 [==============================] - 11s 221us/step - loss: 1.6432 - accuracy: 0.4151 - val_loss: 1.5836 - val_accuracy: 0.4337
# Epoch 8/50
# 50000/50000 [==============================] - 11s 228us/step - loss: 1.6135 - accuracy: 0.4258 - val_loss: 1.5561 - val_accuracy: 0.4506
# Epoch 9/50
# 50000/50000 [==============================] - 12s 232us/step - loss: 1.5901 - accuracy: 0.4365 - val_loss: 1.5365 - val_accuracy: 0.4528
# Epoch 10/50
# 50000/50000 [==============================] - 13s 250us/step - loss: 1.5658 - accuracy: 0.4443 - val_loss: 1.5262 - val_accuracy: 0.4538
# Epoch 11/50
# 50000/50000 [==============================] - 13s 267us/step - loss: 1.5456 - accuracy: 0.4510 - val_loss: 1.5035 - val_accuracy: 0.4632
# Epoch 12/50
# 50000/50000 [==============================] - 12s 241us/step - loss: 1.5241 - accuracy: 0.4584 - val_loss: 1.4821 - val_accuracy: 0.4718
# Epoch 13/50
# 50000/50000 [==============================] - 12s 236us/step - loss: 1.5087 - accuracy: 0.4638 - val_loss: 1.4736 - val_accuracy: 0.4736
# Epoch 14/50
# 50000/50000 [==============================] - 13s 256us/step - loss: 1.4894 - accuracy: 0.4684 - val_loss: 1.4559 - val_accuracy: 0.4799
# Epoch 15/50
# 50000/50000 [==============================] - 12s 248us/step - loss: 1.4747 - accuracy: 0.4778 - val_loss: 1.4381 - val_accuracy: 0.4848
# Epoch 16/50
# 50000/50000 [==============================] - 12s 237us/step - loss: 1.4578 - accuracy: 0.4818 - val_loss: 1.4343 - val_accuracy: 0.4916
# Epoch 17/50
# 50000/50000 [==============================] - 12s 237us/step - loss: 1.4432 - accuracy: 0.4872 - val_loss: 1.4288 - val_accuracy: 0.4870
# Epoch 18/50
# 50000/50000 [==============================] - 12s 236us/step - loss: 1.4272 - accuracy: 0.4927 - val_loss: 1.4138 - val_accuracy: 0.5013
# Epoch 19/50
# 50000/50000 [==============================] - 12s 231us/step - loss: 1.4154 - accuracy: 0.4984 - val_loss: 1.4103 - val_accuracy: 0.5022
# Epoch 20/50
# 50000/50000 [==============================] - 11s 213us/step - loss: 1.4048 - accuracy: 0.5013 - val_loss: 1.3946 - val_accuracy: 0.4995
# Epoch 21/50
# 50000/50000 [==============================] - 10s 204us/step - loss: 1.3887 - accuracy: 0.5066 - val_loss: 1.3867 - val_accuracy: 0.5069
# Epoch 22/50
# 50000/50000 [==============================] - 10s 204us/step - loss: 1.3775 - accuracy: 0.5108 - val_loss: 1.3812 - val_accuracy: 0.5061
# Epoch 23/50
# 50000/50000 [==============================] - 10s 199us/step - loss: 1.3634 - accuracy: 0.5161 - val_loss: 1.3894 - val_accuracy: 0.5016
# Epoch 24/50
# 50000/50000 [==============================] - 10s 203us/step - loss: 1.3531 - accuracy: 0.5177 - val_loss: 1.3630 - val_accuracy: 0.5126
# Epoch 25/50
# 50000/50000 [==============================] - 10s 201us/step - loss: 1.3407 - accuracy: 0.5222 - val_loss: 1.3642 - val_accuracy: 0.5165
# Epoch 26/50
# 50000/50000 [==============================] - 10s 205us/step - loss: 1.3258 - accuracy: 0.5271 - val_loss: 1.3620 - val_accuracy: 0.5153
# Epoch 27/50
# 50000/50000 [==============================] - 10s 203us/step - loss: 1.3200 - accuracy: 0.5287 - val_loss: 1.3644 - val_accuracy: 0.5224
# Epoch 28/50
# 50000/50000 [==============================] - 10s 204us/step - loss: 1.3091 - accuracy: 0.5316 - val_loss: 1.3510 - val_accuracy: 0.5184
# Epoch 29/50
# 50000/50000 [==============================] - 10s 206us/step - loss: 1.2966 - accuracy: 0.5378 - val_loss: 1.3371 - val_accuracy: 0.5222
# Epoch 30/50
# 50000/50000 [==============================] - 10s 201us/step - loss: 1.2895 - accuracy: 0.5431 - val_loss: 1.3420 - val_accuracy: 0.5249
# Epoch 31/50
# 50000/50000 [==============================] - 10s 203us/step - loss: 1.2788 - accuracy: 0.5450 - val_loss: 1.3287 - val_accuracy: 0.5269
# Epoch 32/50
# 50000/50000 [==============================] - 10s 209us/step - loss: 1.2675 - accuracy: 0.5502 - val_loss: 1.3235 - val_accuracy: 0.5332
# Epoch 33/50
# 50000/50000 [==============================] - 10s 204us/step - loss: 1.2597 - accuracy: 0.5507 - val_loss: 1.3327 - val_accuracy: 0.5322
# Epoch 34/50
# 50000/50000 [==============================] - 10s 207us/step - loss: 1.2478 - accuracy: 0.5556 - val_loss: 1.3383 - val_accuracy: 0.5212
# Epoch 35/50
# 50000/50000 [==============================] - 10s 205us/step - loss: 1.2386 - accuracy: 0.5599 - val_loss: 1.3082 - val_accuracy: 0.5384
# Epoch 36/50
# 50000/50000 [==============================] - 10s 202us/step - loss: 1.2298 - accuracy: 0.5606 - val_loss: 1.3117 - val_accuracy: 0.5356
# Epoch 37/50
# 50000/50000 [==============================] - 10s 205us/step - loss: 1.2177 - accuracy: 0.5667 - val_loss: 1.3126 - val_accuracy: 0.5358
# Epoch 38/50
# 50000/50000 [==============================] - 10s 210us/step - loss: 1.2129 - accuracy: 0.5668 - val_loss: 1.3024 - val_accuracy: 0.5368
# Epoch 39/50
# 50000/50000 [==============================] - 10s 202us/step - loss: 1.1991 - accuracy: 0.5723 - val_loss: 1.3161 - val_accuracy: 0.5334
# Epoch 40/50
# 50000/50000 [==============================] - 10s 201us/step - loss: 1.1962 - accuracy: 0.5741 - val_loss: 1.2984 - val_accuracy: 0.5401
# Epoch 41/50
# 50000/50000 [==============================] - 10s 204us/step - loss: 1.1813 - accuracy: 0.5804 - val_loss: 1.3095 - val_accuracy: 0.5388
# Epoch 42/50
# 50000/50000 [==============================] - 10s 201us/step - loss: 1.1752 - accuracy: 0.5810 - val_loss: 1.3047 - val_accuracy: 0.5386
# Epoch 43/50
# 50000/50000 [==============================] - 10s 206us/step - loss: 1.1659 - accuracy: 0.5844 - val_loss: 1.2942 - val_accuracy: 0.5374
# Epoch 44/50
# 50000/50000 [==============================] - 10s 202us/step - loss: 1.1568 - accuracy: 0.5879 - val_loss: 1.2967 - val_accuracy: 0.5388
# Epoch 45/50
# 50000/50000 [==============================] - 10s 203us/step - loss: 1.1489 - accuracy: 0.5915 - val_loss: 1.2875 - val_accuracy: 0.5440
# Epoch 46/50
# 50000/50000 [==============================] - 10s 199us/step - loss: 1.1420 - accuracy: 0.5944 - val_loss: 1.2851 - val_accuracy: 0.5481
# Epoch 47/50
# 50000/50000 [==============================] - 10s 198us/step - loss: 1.1291 - accuracy: 0.5971 - val_loss: 1.2823 - val_accuracy: 0.5456
# Epoch 48/50
# 50000/50000 [==============================] - 10s 199us/step - loss: 1.1212 - accuracy: 0.6005 - val_loss: 1.2824 - val_accuracy: 0.5485
# Epoch 49/50
# 50000/50000 [==============================] - 10s 206us/step - loss: 1.1139 - accuracy: 0.6031 - val_loss: 1.2915 - val_accuracy: 0.5474
# Epoch 50/50
# 50000/50000 [==============================] - 11s 225us/step - loss: 1.1083 - accuracy: 0.6059 - val_loss: 1.2785 - val_accuracy: 0.5491
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-d60a6ff41e8c> in <module>
#      21     train_loss = model.history.history["loss"]
#      22     valid_loss = model.history.history["val_loss"]
# ---> 23     train_acc = model.history.history["accuracyl"]
#      24     valid_acc = model.history.history["val_accuracy"]
#      25
#
# KeyError: 'accuracyl'

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
"""Code Here
將結果繪出
"""
color_bar = ["r", "g", "b", "y", "m", "k"]

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-loss'])),results[cond]['train-loss'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-loss'])),results[cond]['valid-loss'], '--', label=cond, color=color_bar[i])
plt.title("Loss")
plt.legend()
plt.show()

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-acc'])),results[cond]['train-acc'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-acc'])),results[cond]['valid-acc'], '--', label=cond, color=color_bar[i])
plt.title("Accuracy")
plt.legend()
plt.show()
